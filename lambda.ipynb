# %%
emails =['test@gmail.com','python@gmail.com','ml@gmail.com']

# %%
list(map(lambda x:x.split('@')[0],emails))
# Out:
# ['test', 'python', 'ml']

# %%
emails =['test@gmail.com','python@gmail.com','ml@gmail.com']
def user_fetch(email):
    for user in email:
        username=user.split('@')[0]
    return username

# %%
user_fetch(emails)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 user_fetch(emails)
# ----> 2 print(username)
#
# NameError: name 'username' is not defined

# %%
gen=['m','f','m','m','m','hifj','f','f','ffdd']

# %%
list(map(lambda x: 1 if x=='m' else 2 if x=='f'else 'invalid',gen))
# Out:
# [1, 2, 1, 1, 1, 'invalid', 2, 2, 'invalid']

# %%
p =[2,53,52,53,63,7,32,45,74,34,64,67,73,6]

# %%
def even(num):
    if num%2!=0:
        return True
    else:
        return False

# %%
list(filter(even,p))
# Out:
# [53, 53, 63, 7, 45, 67, 73]

# %%
email=['python@gmail.com','ml@rediff.com','hadoop@yahoo.com','bigdata@gmail.com']

# %%
list(filter(lambda x:x.endswith('@gmail.com'),email))
# Out:
# ['python@gmail.com', 'bigdata@gmail.com']

# %%
(lambda x,y:x+y)(5,6)
# Out:
# 11

# %%
def multiple (a,b,c):
    mul = a*b*c
    return mul
multiple(6,4,3)
# Out:
# 72

# %%
(lambda a,b,c :a*b*c)(3,3,5)
# Out:
# 45

# %%
l =[3,5,4,3,21,6]
def sqr(n):
    return n**2
sqr(5)
# Out:
# 25

# %%
list(map(sqr,l))
# Out:
# [9, 25, 16, 9, 441, 36]

# %%
list(map((lambda n :n**2),l))
# Out:
# [9, 25, 16, 9, 441, 36]

# %%
def even (n):
    return n%2==0
list(filter(even ,l))
# Out:
# [4, 6]

# %%
list(filter((lambda n:n%2==0),l))
# Out:
# [4, 6]

# %%
list(map((lambda i :if i not in num) ,l))
# Out:
#   Cell In[3], line 1
#     list(map((lambda i :if i not in num) ,l))
#                         ^
# SyntaxError: invalid syntax

# %%
lst = [1, 2, 3, 2, 4, 1, 5]

seen = set()
result = list(filter(lambda x: not (x in seen or seen.add(x)), lst))

print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
l =[3,5,4,3,21,6]
seen =set()
list(filter(lambda x: not(x in seen or seen.add(x)),l))
# Out:
# [3, 5, 4, 21, 6]

# %%
lst = [1, 2, 3, 2, 4, 1, 5]
A=[]
for i in lst:
    if i not in A:
        A.append(i)
print(A)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst = [1, 2, 3, 2, 4, 1, 5]
max=l[0]
for i in lst:
    if i>max:
        max=i
print(max)
# Out:
# 5

# %%
even=[]
for i in lst:
    if i%2==0:
        even.append(i)
print(even)
# Out:
# [2, 2, 4]

# %%
[i for i in lst if i%2==0]
# Out:
# [2, 2, 4]

# %%
[i**2 for i in lst ]
# Out:
# [1, 4, 9, 4, 16, 1, 25]

# %%
sqr=[]
for i in lst:
    sqr.append(i*i)
print(sqr)
# Out:
# [1, 4, 9, 4, 16, 1, 25]

# %%
lst = [54, 43, 2, 1, 5]
def list_sept(arr):
    for i in arr:
        print(i, end=" ")
list_sept(lst)
# Out:
# 54 43 2 1 5

# %%
a=[1,3,5,2,5,5,6]

# %%
[i*i for i in a]
# Out:
# [1, 9, 25, 4, 25, 25, 36]

# %%
[i for i in a if i%2==0]
# Out:
# [2, 6]

# %%
lst1=['hellow','world']

# %%
l=[]

# %%
[l.append() for i in lst if ]
# Out:
#   Cell In[10], line 1
#     [l.append() for i in lst if ]
#                                 ^
# SyntaxError: invalid syntax

# %%
result=(lambda x,y: x+y)(67,34)

# %%
print(result)
# Out:
# 101
